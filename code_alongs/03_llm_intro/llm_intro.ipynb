# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Why did the mathematician write a poem about numbers? Because he wanted to impress his friends at the "Number Summit"! \n\n😄 Let me know if you want another one—math is *always* funny!')

# %%
print(result.output)
# Out:
# Why did the mathematician write a poem about numbers? Because he wanted to impress his friends at the "Number Summit"!
#
# 😄 Let me know if you want another one—math is *always* funny!

# %%
result = await agent.run("What is the weather in stockholm today?")
print(result.output)
# Out:
# Ah, the weather in Stockholm! 🌤️ But since the data's a bit... let's say *spoiler*—I have a *stupid* habit of making up a joke, here it goes:
#
# The weather in Stockholm today is so *chill*, it’s like someone handed a programmer a broken console—*bam*, no data! Whether it's snow, rain, or a mild Scandinavian breeze, I guess I'll take it with a side of skepticism. Want me to ask you a question about it next? 😄

# %% [markdown]
# # Check Messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 10, 2, 30, 561548, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 10, 2, 30, 561555, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 10, 2, 30, 561844, tzinfo=datetime.timezone.utc), run_id='019d6764-c520-77ed-afb1-87331c054935'),
#  ModelResponse(parts=[TextPart(content="Ah, the weather in Stockholm! 🌤️ But since the data's a bit... let's say *spoiler*—I have a *stupid* habit of making up a joke, here it goes:\n\nThe weather in Stockholm today is so *chill*, it’s like someone handed a programmer a broken console—*bam*, no data! Whether it's snow, rain, or a mild Scandinavian breeze, I guess I'll take it with a side of skepticism. Want me to ask you a question about it next? 😄")], usage=RequestUsage(input_tokens=43, output_tokens=119, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 10, 2, 31, 341512, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 10, 2, 30, tzinfo=TzInfo(0))}, provider_response_id='gen-1775556150-X4R9mzc8Qk1cb33ACNDb', finish_reason='stop', run_id='019d6764-c520-77ed-afb1-87331c054935')]

# %%
len(messages)
# Out:
# 2

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 10, 2, 30, 561548, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 10, 2, 30, 561555, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 10, 2, 30, 561844, tzinfo=datetime.timezone.utc), run_id='019d6764-c520-77ed-afb1-87331c054935')

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content="Ah, the weather in Stockholm! 🌤️ But since the data's a bit... let's say *spoiler*—I have a *stupid* habit of making up a joke, here it goes:\n\nThe weather in Stockholm today is so *chill*, it’s like someone handed a programmer a broken console—*bam*, no data! Whether it's snow, rain, or a mild Scandinavian breeze, I guess I'll take it with a side of skepticism. Want me to ask you a question about it next? 😄")], usage=RequestUsage(input_tokens=43, output_tokens=119, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 10, 2, 31, 341512, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 10, 2, 30, tzinfo=TzInfo(0))}, provider_response_id='gen-1775556150-X4R9mzc8Qk1cb33ACNDb', finish_reason='stop', run_id='019d6764-c520-77ed-afb1-87331c054935')

# %% [markdown]
# # Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=43, output_tokens=119, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "What is the weather in stockholm today?"

len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'
