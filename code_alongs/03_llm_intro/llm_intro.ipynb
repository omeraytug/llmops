# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Why did the math book look sad?\n\nBecause it had too many problems and never finished reading! 😄')

# %%
print(result.output)
# Out:
# Why did the math book look sad?
#
# Because it had too many problems and never finished reading! 😄

# %%
result = await agent.run("What is the weather in stockholm today?")
print(result.output)
# Out:
# Ah, a question wrapped in the mysterious cloak of sarcasm! 🧐 While I can't peek into the weather forecast (as a bot, I can’t access real-time data), I can sure spin up a joke about Stockholm’s climate:
# *"If you're visiting Stockholm today, just remember—once you step out, the sun might say, 'Ah, you're early! The weather’s not ready for you, it’s too busy playing chess with the universe!'"*
#
# Now, if the weather’s nice, you might want to pack a jacket—because even the sun might be hiding something spooky out there. 😄 Is there a certain programming language you’re curious about? I’d love to geek out with you!

# %% [markdown]
# ## Check Messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 11, 37, 20, 728980, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 11, 37, 20, 728982, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 11, 37, 20, 729060, tzinfo=datetime.timezone.utc), run_id='019d67bb-9858-70c8-ad3d-47a8277f30fd'),
#  ModelResponse(parts=[TextPart(content='Ah, a question wrapped in the mysterious cloak of sarcasm! 🧐 While I can\'t peek into the weather forecast (as a bot, I can’t access real-time data), I can sure spin up a joke about Stockholm’s climate:  \n*"If you\'re visiting Stockholm today, just remember—once you step out, the sun might say, \'Ah, you\'re early! The weather’s not ready for you, it’s too busy playing chess with the universe!\'"*  \n\nNow, if the weather’s nice, you might want to pack a jacket—because even the sun might be hiding something spooky out there. 😄 Is there a certain programming language you’re curious about? I’d love to geek out with you!')], usage=RequestUsage(input_tokens=43, output_tokens=157, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 11, 37, 21, 574611, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 11, 37, 20, tzinfo=TzInfo(0))}, provider_response_id='gen-1775561840-UcTbfAEff5YutjmEgdm9', finish_reason='stop', run_id='019d67bb-9858-70c8-ad3d-47a8277f30fd')]

# %%
len(messages)
# Out:
# 2

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 11, 37, 20, 728980, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 11, 37, 20, 728982, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 11, 37, 20, 729060, tzinfo=datetime.timezone.utc), run_id='019d67bb-9858-70c8-ad3d-47a8277f30fd')

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Ah, a question wrapped in the mysterious cloak of sarcasm! 🧐 While I can\'t peek into the weather forecast (as a bot, I can’t access real-time data), I can sure spin up a joke about Stockholm’s climate:  \n*"If you\'re visiting Stockholm today, just remember—once you step out, the sun might say, \'Ah, you\'re early! The weather’s not ready for you, it’s too busy playing chess with the universe!\'"*  \n\nNow, if the weather’s nice, you might want to pack a jacket—because even the sun might be hiding something spooky out there. 😄 Is there a certain programming language you’re curious about? I’d love to geek out with you!')], usage=RequestUsage(input_tokens=43, output_tokens=157, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 11, 37, 21, 574611, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 11, 37, 20, tzinfo=TzInfo(0))}, provider_response_id='gen-1775561840-UcTbfAEff5YutjmEgdm9', finish_reason='stop', run_id='019d67bb-9858-70c8-ad3d-47a8277f30fd')

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=43, output_tokens=157, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "What is the weather in stockholm today?"

len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'

# %%
len(system_prompt.split())
# Out:
# 17

# %% [markdown]
# user prompt: 7 words
#
# system_prompt: 17 words
#
# total: 24 words
#
# computed_tokens_approx: 24*1.3 + 31 tokens
#
# input_tokens: 43 tokens
#
# tokens left used for structuring inputs and outputs

# %%
# bot answer computed tokens approximate
len(result.output.split())*1.3
# Out:
# 139.1

# %% [markdown]
# ## Temperature
#
# - higher temperature -> more creativity
# - lower temperature -> closer to deterministic

# %%
from pydantic_ai import ModelSettings

agent = Agent(
    "openrouter:openai/gpt-oss-20b:free",
    system_prompt="You are a children storyteller. Answer max 2 sentences.",
    model_settings=ModelSettings(temperature=0)
)

prompt = "A goldfish in an aquarium ... "

result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Glimmer twirled around a silver leaf, dreaming of the big blue ocean beyond the glass. One sunny morning, a gentle splash of water carried a bright, swirling bubble that whispered, “Follow me, Glimmer, and the sea will be yours!”

# %%
result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Glimmer twirled around a silver leaf, dreaming of the big blue ocean beyond the glass. One sunny morning, a gentle splash of water carried a bright, swirling bubble that whispered, “Follow me, Glimmer, and adventure awaits!”

# %%
agent.model_settings = ModelSettings(temperature=2) 
result = await agent.run(prompt)
print(result.output)

# %%
# note reasoning tokens as this is a reasoning model
result.usage()
# Out:
# RunUsage(input_tokens=91, cache_read_tokens=80, output_tokens=75, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 5, 'image_tokens': 0}, requests=1)

# %% [markdown]
# ## Multimodal inputs
#
# - text
# - audio
# - image
# - video

# %%
from pathlib import Path

image_agent = Agent(
    "openrouter:qwen/qwen3.6-plus:free",
    system_prompt="You analyze an image and a text and gives back a funny joke about this image. Max 3 sentences",

)

Path("bella.png").read_bytes()
